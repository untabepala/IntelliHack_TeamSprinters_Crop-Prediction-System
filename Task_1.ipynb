# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import joblib

# %%
dataset = pd.read_csv("Crop_Dataset.csv")

# %%
print(dataset.head())
print(dataset.info())
print(dataset.describe())
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  Total_Nutrients  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536              175
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537              184
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248              159
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034              149
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340              162
#
#    Temperature_Humidity  Log_Rainfall  Label  Label_Encoded
# 0           1712.196283      5.317804  wheat              0
# 1           1748.595734      5.427834  wheat              0
# 2           1893.744627      5.579595  wheat              0
# 3           2123.482908      5.496611  wheat              0
# 4           1642.720357      5.574878  wheat              0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   N                     2200 non-null   int64
#  1   P                     2200 non-null   int64
#  2   K                     2200 non-null   int64
#  3   temperature           2200 non-null   float64
#  4   humidity              2200 non-null   float64
#  5   ph                    2200 non-null   float64
#  6   rainfall              2200 non-null   float64
#  7   Total_Nutrients       2200 non-null   int64
#  8   Temperature_Humidity  2200 non-null   float64
#  9   Log_Rainfall          2200 non-null   float64
#  10  Label                 2200 non-null   object
#  11  Label_Encoded         2200 non-null   int64
# dtypes: float64(6), int64(5), object(1)
# memory usage: 206.4+ KB
# None
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall  Total_Nutrients  Temperature_Humidity  \
# count  2200.000000  2200.000000      2200.000000           2200.000000
# mean      6.469480   103.463655       152.063636           1854.231566
# std       0.773938    54.958389        79.918669            699.366334
# min       3.504752    20.211267        17.000000            247.613182
# 25%       5.971693    64.551686        94.000000           1479.558114
# 50%       6.425045    94.867624       146.000000           1927.883340
# 75%       6.923643   124.267508       179.000000           2255.752423
# max       9.935091   298.560117       385.000000           4073.159566
#
#        Log_Rainfall  Label_Encoded
# count   2200.000000    2200.000000
# mean       4.508730      10.500000
# std        0.545400       6.345731
# min        3.054533       0.000000
# 25%        4.182839       5.000000
# 50%        4.562968      10.500000
# 75%        4.830451      16.000000
# max        5.702315      21.000000

# %%
label_encoder = LabelEncoder()
dataset['Label'] = label_encoder.fit_transform(dataset['Label'])

# %%
X = dataset.drop(columns=['Label','Label_Encoded'])
y = dataset['Label']

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9931818181818182

# %%
y_pred_probabilities = model.predict_proba(X_test)

# %%
top_three_classes = (-y_pred_probabilities).argsort()[:, :3]

# %%
predicted_crop_names = []

# %%
for sample_classes in top_three_classes:
    predicted_crop_names.append(label_encoder.inverse_transform(sample_classes))

# %%
for i, crops in enumerate(predicted_crop_names):
    print(f"Top 3 crops for sample {i + 1}: {crops}")
# Out:
# Top 3 crops for sample 1: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 2: ['plums' 'apples' 'tomatoes']
# Top 3 crops for sample 3: ['strawberries' 'tomatoes' 'apples']
# Top 3 crops for sample 4: ['strawberries' 'apples' 'tomatoes']
# Top 3 crops for sample 5: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 6: ['beets' 'apples' 'tomatoes']
# Top 3 crops for sample 7: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 8: ['brussels_sprouts' 'barley' 'apples']
# Top 3 crops for sample 9: ['cabbage' 'apples' 'tomatoes']
# Top 3 crops for sample 10: ['peas' 'apples' 'tomatoes']
# Top 3 crops for sample 11: ['beans' 'apples' 'tomatoes']
# Top 3 crops for sample 12: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 13: ['turnips' 'apples' 'tomatoes']
# Top 3 crops for sample 14: ['rapeseed' 'tomatoes' 'wheat']
# Top 3 crops for sample 15: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 16: ['turnips' 'apples' 'blackcurrants']
# Top 3 crops for sample 17: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 18: ['barley' 'potatoes' 'apples']
# Top 3 crops for sample 19: ['strawberries' 'carrots' 'apples']
# Top 3 crops for sample 20: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 21: ['tomatoes' 'apples' 'strawberries']
# Top 3 crops for sample 22: ['strawberries' 'apples' 'tomatoes']
# Top 3 crops for sample 23: ['blackcurrants' 'turnips' 'apples']
# Top 3 crops for sample 24: ['strawberries' 'beans' 'apples']
# Top 3 crops for sample 25: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 26: ['rapeseed' 'apples' 'tomatoes']
# Top 3 crops for sample 27: ['cabbage' 'peas' 'strawberries']
# Top 3 crops for sample 28: ['blackcurrants' 'apples' 'tomatoes']
# Top 3 crops for sample 29: ['cauliflower' 'tomatoes' 'beans']
# Top 3 crops for sample 30: ['wheat' 'rapeseed' 'tomatoes']
# Top 3 crops for sample 31: ['turnips' 'blackcurrants' 'apples']
# Top 3 crops for sample 32: ['brussels_sprouts' 'peas' 'cabbage']
# Top 3 crops for sample 33: ['rapeseed' 'tomatoes' 'wheat']
# Top 3 crops for sample 34: ['peas' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 35: ['rapeseed' 'tomatoes' 'wheat']
# Top 3 crops for sample 36: ['beans' 'brussels_sprouts' 'peas']
# Top 3 crops for sample 37: ['rapeseed' 'wheat' 'tomatoes']
# Top 3 crops for sample 38: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 39: ['lettuce' 'spinach' 'tomatoes']
# Top 3 crops for sample 40: ['spinach' 'brussels_sprouts' 'peas']
# Top 3 crops for sample 41: ['strawberries' 'carrots' 'wheat']
# Top 3 crops for sample 42: ['beets' 'apples' 'tomatoes']
# Top 3 crops for sample 43: ['beans' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 44: ['barley' 'tomatoes' 'brussels_sprouts']
# Top 3 crops for sample 45: ['cabbage' 'apples' 'tomatoes']
# Top 3 crops for sample 46: ['barley' 'cauliflower' 'beans']
# Top 3 crops for sample 47: ['cauliflower' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 48: ['apples' 'wheat' 'beans']
# Top 3 crops for sample 49: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 50: ['barley' 'brussels_sprouts' 'beans']
# Top 3 crops for sample 51: ['beans' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 52: ['tomatoes' 'barley' 'apples']
# Top 3 crops for sample 53: ['cherries' 'apples' 'tomatoes']
# Top 3 crops for sample 54: ['cabbage' 'beets' 'turnips']
# Top 3 crops for sample 55: ['tomatoes' 'barley' 'turnips']
# Top 3 crops for sample 56: ['spinach' 'apples' 'tomatoes']
# Top 3 crops for sample 57: ['potatoes' 'cabbage' 'plums']
# Top 3 crops for sample 58: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 59: ['carrots' 'apples' 'tomatoes']
# Top 3 crops for sample 60: ['beans' 'brussels_sprouts' 'peas']
# Top 3 crops for sample 61: ['plums' 'apples' 'tomatoes']
# Top 3 crops for sample 62: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 63: ['peas' 'brussels_sprouts' 'cauliflower']
# Top 3 crops for sample 64: ['blackcurrants' 'turnips' 'apples']
# Top 3 crops for sample 65: ['strawberries' 'cabbage' 'peas']
# Top 3 crops for sample 66: ['cauliflower' 'beans' 'barley']
# Top 3 crops for sample 67: ['blackcurrants' 'apples' 'tomatoes']
# Top 3 crops for sample 68: ['wheat' 'tomatoes' 'strawberries']
# Top 3 crops for sample 69: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 70: ['cauliflower' 'apples' 'tomatoes']
# Top 3 crops for sample 71: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 72: ['apples' 'strawberries' 'tomatoes']
# Top 3 crops for sample 73: ['rapeseed' 'wheat' 'tomatoes']
# Top 3 crops for sample 74: ['carrots' 'apples' 'tomatoes']
# Top 3 crops for sample 75: ['beans' 'peas' 'brussels_sprouts']
# Top 3 crops for sample 76: ['strawberries' 'apples' 'tomatoes']
# Top 3 crops for sample 77: ['carrots' 'apples' 'tomatoes']
# Top 3 crops for sample 78: ['potatoes' 'barley' 'cabbage']
# Top 3 crops for sample 79: ['plums' 'apples' 'tomatoes']
# Top 3 crops for sample 80: ['blackcurrants' 'apples' 'tomatoes']
# Top 3 crops for sample 81: ['tomatoes' 'beets' 'barley']
# Top 3 crops for sample 82: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 83: ['wheat' 'rapeseed' 'tomatoes']
# Top 3 crops for sample 84: ['brussels_sprouts' 'beans' 'peas']
# Top 3 crops for sample 85: ['blackcurrants' 'apples' 'tomatoes']
# Top 3 crops for sample 86: ['beets' 'cauliflower' 'barley']
# Top 3 crops for sample 87: ['tomatoes' 'apples' 'strawberries']
# Top 3 crops for sample 88: ['brussels_sprouts' 'peas' 'apples']
# Top 3 crops for sample 89: ['beans' 'apples' 'tomatoes']
# Top 3 crops for sample 90: ['turnips' 'strawberries' 'blackcurrants']
# Top 3 crops for sample 91: ['barley' 'apples' 'tomatoes']
# Top 3 crops for sample 92: ['brussels_sprouts' 'beets' 'apples']
# Top 3 crops for sample 93: ['potatoes' 'beans' 'apples']
# Top 3 crops for sample 94: ['strawberries' 'rapeseed' 'wheat']
# Top 3 crops for sample 95: ['cauliflower' 'barley' 'tomatoes']
# Top 3 crops for sample 96: ['brussels_sprouts' 'beans' 'cauliflower']
# Top 3 crops for sample 97: ['spinach' 'apples' 'tomatoes']
# Top 3 crops for sample 98: ['tomatoes' 'barley' 'beets']
# Top 3 crops for sample 99: ['beans' 'brussels_sprouts' 'peas']
# Top 3 crops for sample 100: ['peas' 'brussels_sprouts' 'cabbage']
# Top 3 crops for sample 101: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 102: ['wheat' 'rapeseed' 'strawberries']
# Top 3 crops for sample 103: ['blackcurrants' 'apples' 'tomatoes']
# Top 3 crops for sample 104: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 105: ['plums' 'apples' 'tomatoes']
# Top 3 crops for sample 106: ['spinach' 'apples' 'tomatoes']
# Top 3 crops for sample 107: ['plums' 'apples' 'tomatoes']
# Top 3 crops for sample 108: ['carrots' 'potatoes' 'plums']
# Top 3 crops for sample 109: ['cauliflower' 'apples' 'tomatoes']
# Top 3 crops for sample 110: ['brussels_sprouts' 'peas' 'apples']
# Top 3 crops for sample 111: ['carrots' 'apples' 'tomatoes']
# Top 3 crops for sample 112: ['rapeseed' 'wheat' 'carrots']
# Top 3 crops for sample 113: ['potatoes' 'barley' 'beans']
# Top 3 crops for sample 114: ['turnips' 'apples' 'tomatoes']
# Top 3 crops for sample 115: ['cauliflower' 'apples' 'tomatoes']
# Top 3 crops for sample 116: ['lettuce' 'barley' 'strawberries']
# Top 3 crops for sample 117: ['barley' 'tomatoes' 'cauliflower']
# Top 3 crops for sample 118: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 119: ['turnips' 'apples' 'tomatoes']
# Top 3 crops for sample 120: ['wheat' 'rapeseed' 'tomatoes']
# Top 3 crops for sample 121: ['cauliflower' 'beans' 'apples']
# Top 3 crops for sample 122: ['cherries' 'apples' 'tomatoes']
# Top 3 crops for sample 123: ['beans' 'cauliflower' 'brussels_sprouts']
# Top 3 crops for sample 124: ['apples' 'strawberries' 'turnips']
# Top 3 crops for sample 125: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 126: ['beans' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 127: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 128: ['barley' 'beans' 'brussels_sprouts']
# Top 3 crops for sample 129: ['carrots' 'potatoes' 'apples']
# Top 3 crops for sample 130: ['brussels_sprouts' 'peas' 'apples']
# Top 3 crops for sample 131: ['carrots' 'strawberries' 'rapeseed']
# Top 3 crops for sample 132: ['spinach' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 133: ['turnips' 'apples' 'tomatoes']
# Top 3 crops for sample 134: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 135: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 136: ['blackcurrants' 'apples' 'tomatoes']
# Top 3 crops for sample 137: ['cauliflower' 'beans' 'apples']
# Top 3 crops for sample 138: ['carrots' 'potatoes' 'apples']
# Top 3 crops for sample 139: ['carrots' 'apples' 'tomatoes']
# Top 3 crops for sample 140: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 141: ['spinach' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 142: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 143: ['cabbage' 'apples' 'tomatoes']
# Top 3 crops for sample 144: ['brussels_sprouts' 'beans' 'cauliflower']
# Top 3 crops for sample 145: ['apples' 'wheat' 'beans']
# Top 3 crops for sample 146: ['barley' 'potatoes' 'rapeseed']
# Top 3 crops for sample 147: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 148: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 149: ['spinach' 'apples' 'tomatoes']
# Top 3 crops for sample 150: ['brussels_sprouts' 'beans' 'barley']
# Top 3 crops for sample 151: ['cabbage' 'apples' 'tomatoes']
# Top 3 crops for sample 152: ['peas' 'brussels_sprouts' 'strawberries']
# Top 3 crops for sample 153: ['plums' 'raspberries' 'rapeseed']
# Top 3 crops for sample 154: ['cabbage' 'apples' 'tomatoes']
# Top 3 crops for sample 155: ['cauliflower' 'beans' 'barley']
# Top 3 crops for sample 156: ['cauliflower' 'beans' 'barley']
# Top 3 crops for sample 157: ['cauliflower' 'apples' 'tomatoes']
# Top 3 crops for sample 158: ['spinach' 'apples' 'tomatoes']
# Top 3 crops for sample 159: ['barley' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 160: ['rapeseed' 'apples' 'tomatoes']
# Top 3 crops for sample 161: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 162: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 163: ['blackcurrants' 'apples' 'cabbage']
# Top 3 crops for sample 164: ['potatoes' 'apples' 'tomatoes']
# Top 3 crops for sample 165: ['wheat' 'tomatoes' 'cauliflower']
# Top 3 crops for sample 166: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 167: ['cherries' 'apples' 'tomatoes']
# Top 3 crops for sample 168: ['peas' 'beans' 'apples']
# Top 3 crops for sample 169: ['plums' 'apples' 'tomatoes']
# Top 3 crops for sample 170: ['cherries' 'apples' 'tomatoes']
# Top 3 crops for sample 171: ['cherries' 'apples' 'tomatoes']
# Top 3 crops for sample 172: ['beans' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 173: ['turnips' 'apples' 'tomatoes']
# Top 3 crops for sample 174: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 175: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 176: ['barley' 'tomatoes' 'apples']
# Top 3 crops for sample 177: ['peas' 'beans' 'apples']
# Top 3 crops for sample 178: ['cherries' 'apples' 'tomatoes']
# Top 3 crops for sample 179: ['plums' 'apples' 'tomatoes']
# Top 3 crops for sample 180: ['rapeseed' 'wheat' 'tomatoes']
# Top 3 crops for sample 181: ['tomatoes' 'rapeseed' 'apples']
# Top 3 crops for sample 182: ['tomatoes' 'rapeseed' 'apples']
# Top 3 crops for sample 183: ['spinach' 'apples' 'tomatoes']
# Top 3 crops for sample 184: ['rapeseed' 'wheat' 'tomatoes']
# Top 3 crops for sample 185: ['brussels_sprouts' 'cabbage' 'apples']
# Top 3 crops for sample 186: ['spinach' 'apples' 'tomatoes']
# Top 3 crops for sample 187: ['carrots' 'rapeseed' 'apples']
# Top 3 crops for sample 188: ['spinach' 'cauliflower' 'apples']
# Top 3 crops for sample 189: ['apples' 'blackcurrants' 'beets']
# Top 3 crops for sample 190: ['strawberries' 'turnips' 'apples']
# Top 3 crops for sample 191: ['strawberries' 'beans' 'apples']
# Top 3 crops for sample 192: ['cabbage' 'apples' 'tomatoes']
# Top 3 crops for sample 193: ['beets' 'turnips' 'apples']
# Top 3 crops for sample 194: ['turnips' 'apples' 'blackcurrants']
# Top 3 crops for sample 195: ['plums' 'strawberries' 'apples']
# Top 3 crops for sample 196: ['spinach' 'cauliflower' 'apples']
# Top 3 crops for sample 197: ['barley' 'beans' 'potatoes']
# Top 3 crops for sample 198: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 199: ['beans' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 200: ['lettuce' 'spinach' 'tomatoes']
# Top 3 crops for sample 201: ['cherries' 'apples' 'tomatoes']
# Top 3 crops for sample 202: ['cherries' 'apples' 'tomatoes']
# Top 3 crops for sample 203: ['carrots' 'apples' 'tomatoes']
# Top 3 crops for sample 204: ['potatoes' 'apples' 'tomatoes']
# Top 3 crops for sample 205: ['wheat' 'tomatoes' 'strawberries']
# Top 3 crops for sample 206: ['turnips' 'blackcurrants' 'apples']
# Top 3 crops for sample 207: ['cabbage' 'beans' 'apples']
# Top 3 crops for sample 208: ['carrots' 'apples' 'tomatoes']
# Top 3 crops for sample 209: ['rapeseed' 'wheat' 'tomatoes']
# Top 3 crops for sample 210: ['cabbage' 'apples' 'tomatoes']
# Top 3 crops for sample 211: ['barley' 'potatoes' 'beans']
# Top 3 crops for sample 212: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 213: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 214: ['lettuce' 'carrots' 'tomatoes']
# Top 3 crops for sample 215: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 216: ['wheat' 'rapeseed' 'tomatoes']
# Top 3 crops for sample 217: ['spinach' 'lettuce' 'tomatoes']
# Top 3 crops for sample 218: ['strawberries' 'beans' 'turnips']
# Top 3 crops for sample 219: ['tomatoes' 'barley' 'beets']
# Top 3 crops for sample 220: ['beans' 'apples' 'tomatoes']
# Top 3 crops for sample 221: ['spinach' 'apples' 'tomatoes']
# Top 3 crops for sample 222: ['beets' 'apples' 'tomatoes']
# Top 3 crops for sample 223: ['beets' 'apples' 'tomatoes']
# Top 3 crops for sample 224: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 225: ['strawberries' 'apples' 'tomatoes']
# Top 3 crops for sample 226: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 227: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 228: ['turnips' 'blackcurrants' 'apples']
# Top 3 crops for sample 229: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 230: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 231: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 232: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 233: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 234: ['beets' 'cauliflower' 'barley']
# Top 3 crops for sample 235: ['beets' 'apples' 'tomatoes']
# Top 3 crops for sample 236: ['potatoes' 'carrots' 'barley']
# Top 3 crops for sample 237: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 238: ['turnips' 'blackcurrants' 'apples']
# Top 3 crops for sample 239: ['wheat' 'rapeseed' 'strawberries']
# Top 3 crops for sample 240: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 241: ['tomatoes' 'barley' 'cauliflower']
# Top 3 crops for sample 242: ['strawberries' 'turnips' 'rapeseed']
# Top 3 crops for sample 243: ['brussels_sprouts' 'peas' 'apples']
# Top 3 crops for sample 244: ['barley' 'wheat' 'beans']
# Top 3 crops for sample 245: ['beets' 'apples' 'tomatoes']
# Top 3 crops for sample 246: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 247: ['cauliflower' 'beets' 'beans']
# Top 3 crops for sample 248: ['cabbage' 'peas' 'apples']
# Top 3 crops for sample 249: ['tomatoes' 'apples' 'strawberries']
# Top 3 crops for sample 250: ['cherries' 'apples' 'tomatoes']
# Top 3 crops for sample 251: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 252: ['potatoes' 'carrots' 'barley']
# Top 3 crops for sample 253: ['cauliflower' 'apples' 'tomatoes']
# Top 3 crops for sample 254: ['wheat' 'tomatoes' 'strawberries']
# Top 3 crops for sample 255: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 256: ['turnips' 'apples' 'beets']
# Top 3 crops for sample 257: ['tomatoes' 'rapeseed' 'apples']
# Top 3 crops for sample 258: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 259: ['potatoes' 'barley' 'apples']
# Top 3 crops for sample 260: ['rapeseed' 'wheat' 'tomatoes']
# Top 3 crops for sample 261: ['beets' 'turnips' 'apples']
# Top 3 crops for sample 262: ['carrots' 'barley' 'strawberries']
# Top 3 crops for sample 263: ['strawberries' 'beans' 'apples']
# Top 3 crops for sample 264: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 265: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 266: ['wheat' 'rapeseed' 'tomatoes']
# Top 3 crops for sample 267: ['cauliflower' 'beets' 'brussels_sprouts']
# Top 3 crops for sample 268: ['brussels_sprouts' 'beans' 'blackcurrants']
# Top 3 crops for sample 269: ['cabbage' 'apples' 'tomatoes']
# Top 3 crops for sample 270: ['rapeseed' 'wheat' 'strawberries']
# Top 3 crops for sample 271: ['turnips' 'strawberries' 'apples']
# Top 3 crops for sample 272: ['cherries' 'apples' 'tomatoes']
# Top 3 crops for sample 273: ['brussels_sprouts' 'beans' 'cauliflower']
# Top 3 crops for sample 274: ['rapeseed' 'strawberries' 'apples']
# Top 3 crops for sample 275: ['barley' 'potatoes' 'brussels_sprouts']
# Top 3 crops for sample 276: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 277: ['barley' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 278: ['lettuce' 'spinach' 'tomatoes']
# Top 3 crops for sample 279: ['carrots' 'apples' 'tomatoes']
# Top 3 crops for sample 280: ['rapeseed' 'wheat' 'tomatoes']
# Top 3 crops for sample 281: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 282: ['rapeseed' 'wheat' 'tomatoes']
# Top 3 crops for sample 283: ['beets' 'cauliflower' 'barley']
# Top 3 crops for sample 284: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 285: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 286: ['carrots' 'apples' 'tomatoes']
# Top 3 crops for sample 287: ['cauliflower' 'apples' 'tomatoes']
# Top 3 crops for sample 288: ['beans' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 289: ['blackcurrants' 'apples' 'tomatoes']
# Top 3 crops for sample 290: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 291: ['plums' 'apples' 'tomatoes']
# Top 3 crops for sample 292: ['carrots' 'potatoes' 'plums']
# Top 3 crops for sample 293: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 294: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 295: ['tomatoes' 'apples' 'strawberries']
# Top 3 crops for sample 296: ['cauliflower' 'beans' 'barley']
# Top 3 crops for sample 297: ['blackcurrants' 'apples' 'tomatoes']
# Top 3 crops for sample 298: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 299: ['apples' 'rapeseed' 'cauliflower']
# Top 3 crops for sample 300: ['strawberries' 'potatoes' 'apples']
# Top 3 crops for sample 301: ['plums' 'apples' 'tomatoes']
# Top 3 crops for sample 302: ['brussels_sprouts' 'beets' 'beans']
# Top 3 crops for sample 303: ['strawberries' 'wheat' 'rapeseed']
# Top 3 crops for sample 304: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 305: ['turnips' 'apples' 'tomatoes']
# Top 3 crops for sample 306: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 307: ['strawberries' 'cabbage' 'peas']
# Top 3 crops for sample 308: ['peas' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 309: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 310: ['turnips' 'apples' 'tomatoes']
# Top 3 crops for sample 311: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 312: ['beets' 'brussels_sprouts' 'turnips']
# Top 3 crops for sample 313: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 314: ['turnips' 'blackcurrants' 'wheat']
# Top 3 crops for sample 315: ['plums' 'apples' 'tomatoes']
# Top 3 crops for sample 316: ['spinach' 'apples' 'tomatoes']
# Top 3 crops for sample 317: ['cabbage' 'apples' 'tomatoes']
# Top 3 crops for sample 318: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 319: ['plums' 'apples' 'tomatoes']
# Top 3 crops for sample 320: ['spinach' 'apples' 'tomatoes']
# Top 3 crops for sample 321: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 322: ['beets' 'apples' 'tomatoes']
# Top 3 crops for sample 323: ['rapeseed' 'wheat' 'strawberries']
# Top 3 crops for sample 324: ['beans' 'brussels_sprouts' 'barley']
# Top 3 crops for sample 325: ['lettuce' 'tomatoes' 'strawberries']
# Top 3 crops for sample 326: ['carrots' 'apples' 'tomatoes']
# Top 3 crops for sample 327: ['beans' 'spinach' 'apples']
# Top 3 crops for sample 328: ['cauliflower' 'beans' 'strawberries']
# Top 3 crops for sample 329: ['strawberries' 'tomatoes' 'apples']
# Top 3 crops for sample 330: ['cauliflower' 'beans' 'beets']
# Top 3 crops for sample 331: ['cabbage' 'apples' 'tomatoes']
# Top 3 crops for sample 332: ['apples' 'strawberries' 'tomatoes']
# Top 3 crops for sample 333: ['potatoes' 'apples' 'tomatoes']
# Top 3 crops for sample 334: ['cherries' 'apples' 'tomatoes']
# Top 3 crops for sample 335: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 336: ['peas' 'beans' 'cabbage']
# Top 3 crops for sample 337: ['carrots' 'strawberries' 'apples']
# Top 3 crops for sample 338: ['rapeseed' 'tomatoes' 'wheat']
# Top 3 crops for sample 339: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 340: ['turnips' 'carrots' 'apples']
# Top 3 crops for sample 341: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 342: ['cabbage' 'apples' 'tomatoes']
# Top 3 crops for sample 343: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 344: ['tomatoes' 'cauliflower' 'rapeseed']
# Top 3 crops for sample 345: ['tomatoes' 'rapeseed' 'wheat']
# Top 3 crops for sample 346: ['cauliflower' 'apples' 'tomatoes']
# Top 3 crops for sample 347: ['rapeseed' 'wheat' 'tomatoes']
# Top 3 crops for sample 348: ['spinach' 'apples' 'tomatoes']
# Top 3 crops for sample 349: ['carrots' 'apples' 'tomatoes']
# Top 3 crops for sample 350: ['barley' 'apples' 'tomatoes']
# Top 3 crops for sample 351: ['rapeseed' 'apples' 'tomatoes']
# Top 3 crops for sample 352: ['barley' 'potatoes' 'cauliflower']
# Top 3 crops for sample 353: ['cauliflower' 'apples' 'tomatoes']
# Top 3 crops for sample 354: ['beets' 'apples' 'tomatoes']
# Top 3 crops for sample 355: ['spinach' 'apples' 'tomatoes']
# Top 3 crops for sample 356: ['turnips' 'apples' 'beans']
# Top 3 crops for sample 357: ['plums' 'apples' 'tomatoes']
# Top 3 crops for sample 358: ['beans' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 359: ['barley' 'brussels_sprouts' 'tomatoes']
# Top 3 crops for sample 360: ['wheat' 'strawberries' 'rapeseed']
# Top 3 crops for sample 361: ['brussels_sprouts' 'peas' 'apples']
# Top 3 crops for sample 362: ['spinach' 'blackcurrants' 'cauliflower']
# Top 3 crops for sample 363: ['beets' 'apples' 'tomatoes']
# Top 3 crops for sample 364: ['potatoes' 'apples' 'tomatoes']
# Top 3 crops for sample 365: ['strawberries' 'wheat' 'tomatoes']
# Top 3 crops for sample 366: ['brussels_sprouts' 'peas' 'beets']
# Top 3 crops for sample 367: ['potatoes' 'apples' 'tomatoes']
# Top 3 crops for sample 368: ['cabbage' 'apples' 'tomatoes']
# Top 3 crops for sample 369: ['blackcurrants' 'beets' 'apples']
# Top 3 crops for sample 370: ['rapeseed' 'wheat' 'tomatoes']
# Top 3 crops for sample 371: ['beans' 'cauliflower' 'peas']
# Top 3 crops for sample 372: ['cabbage' 'apples' 'tomatoes']
# Top 3 crops for sample 373: ['tomatoes' 'rapeseed' 'apples']
# Top 3 crops for sample 374: ['carrots' 'apples' 'tomatoes']
# Top 3 crops for sample 375: ['cauliflower' 'peas' 'apples']
# Top 3 crops for sample 376: ['strawberries' 'wheat' 'beans']
# Top 3 crops for sample 377: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 378: ['turnips' 'apples' 'tomatoes']
# Top 3 crops for sample 379: ['barley' 'beans' 'cabbage']
# Top 3 crops for sample 380: ['beets' 'turnips' 'apples']
# Top 3 crops for sample 381: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 382: ['pears' 'apples' 'tomatoes']
# Top 3 crops for sample 383: ['peas' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 384: ['rapeseed' 'tomatoes' 'apples']
# Top 3 crops for sample 385: ['brussels_sprouts' 'peas' 'apples']
# Top 3 crops for sample 386: ['peas' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 387: ['apples' 'blackcurrants' 'turnips']
# Top 3 crops for sample 388: ['beans' 'brussels_sprouts' 'apples']
# Top 3 crops for sample 389: ['rapeseed' 'apples' 'tomatoes']
# Top 3 crops for sample 390: ['cabbage' 'apples' 'tomatoes']
# Top 3 crops for sample 391: ['potatoes' 'strawberries' 'apples']
# Top 3 crops for sample 392: ['plums' 'apples' 'tomatoes']
# Top 3 crops for sample 393: ['pears' 'strawberries' 'apples']
# Top 3 crops for sample 394: ['cherries' 'apples' 'tomatoes']
# Top 3 crops for sample 395: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 396: ['cherries' 'apples' 'tomatoes']
# Top 3 crops for sample 397: ['plums' 'apples' 'tomatoes']
# Top 3 crops for sample 398: ['wheat' 'rapeseed' 'strawberries']
# Top 3 crops for sample 399: ['beets' 'apples' 'tomatoes']
# Top 3 crops for sample 400: ['beets' 'tomatoes' 'apples']
# Top 3 crops for sample 401: ['tomatoes' 'potatoes' 'rapeseed']
# Top 3 crops for sample 402: ['turnips' 'apples' 'tomatoes']
# Top 3 crops for sample 403: ['carrots' 'apples' 'tomatoes']
# Top 3 crops for sample 404: ['cherries' 'apples' 'tomatoes']
# Top 3 crops for sample 405: ['rapeseed' 'wheat' 'tomatoes']
# Top 3 crops for sample 406: ['blackcurrants' 'turnips' 'beets']
# Top 3 crops for sample 407: ['potatoes' 'apples' 'tomatoes']
# Top 3 crops for sample 408: ['beets' 'apples' 'tomatoes']
# Top 3 crops for sample 409: ['strawberries' 'tomatoes' 'apples']
# Top 3 crops for sample 410: ['raspberries' 'apples' 'tomatoes']
# Top 3 crops for sample 411: ['brussels_sprouts' 'apples' 'tomatoes']
# Top 3 crops for sample 412: ['rapeseed' 'apples' 'tomatoes']
# Top 3 crops for sample 413: ['lettuce' 'spinach' 'tomatoes']
# Top 3 crops for sample 414: ['brussels_sprouts' 'apples' 'tomatoes']
# Top 3 crops for sample 415: ['turnips' 'blackcurrants' 'rapeseed']
# Top 3 crops for sample 416: ['plums' 'apples' 'tomatoes']
# Top 3 crops for sample 417: ['brussels_sprouts' 'barley' 'cauliflower']
# Top 3 crops for sample 418: ['potatoes' 'carrots' 'lettuce']
# Top 3 crops for sample 419: ['strawberries' 'rapeseed' 'apples']
# Top 3 crops for sample 420: ['plums' 'apples' 'tomatoes']
# Top 3 crops for sample 421: ['peas' 'brussels_sprouts' 'beans']
# Top 3 crops for sample 422: ['wheat' 'rapeseed' 'tomatoes']
# Top 3 crops for sample 423: ['apples' 'tomatoes' 'strawberries']
# Top 3 crops for sample 424: ['brussels_sprouts' 'peas' 'apples']
# Top 3 crops for sample 425: ['brussels_sprouts' 'peas' 'beans']
# Top 3 crops for sample 426: ['barley' 'apples' 'tomatoes']
# Top 3 crops for sample 427: ['wheat' 'rapeseed' 'strawberries']
# Top 3 crops for sample 428: ['barley' 'potatoes' 'rapeseed']
# Top 3 crops for sample 429: ['apples' 'blackcurrants' 'tomatoes']
# Top 3 crops for sample 430: ['blackcurrants' 'apples' 'tomatoes']
# Top 3 crops for sample 431: ['turnips' 'apples' 'tomatoes']
# Top 3 crops for sample 432: ['spinach' 'apples' 'tomatoes']
# Top 3 crops for sample 433: ['plums' 'strawberries' 'apples']
# Top 3 crops for sample 434: ['cabbage' 'peas' 'apples']
# Top 3 crops for sample 435: ['beans' 'brussels_sprouts' 'barley']
# Top 3 crops for sample 436: ['wheat' 'rapeseed' 'tomatoes']
# Top 3 crops for sample 437: ['wheat' 'tomatoes' 'strawberries']
# Top 3 crops for sample 438: ['potatoes' 'apples' 'tomatoes']
# Top 3 crops for sample 439: ['potatoes' 'barley' 'apples']
# Top 3 crops for sample 440: ['cauliflower' 'lettuce' 'spinach']

# %%
total_samples = len(y_test)
correct_predictions = 0

# %%
for true_label, top_classes in zip(y_test, top_three_classes):
    if true_label in top_classes:
        correct_predictions += 1

# %%
accuracy_top_three = correct_predictions / total_samples
print("Accuracy (Top Three):", accuracy_top_three)
# Out:
# Accuracy (Top Three): 1.0

# %%
joblib.dump(model,"task1.pickle")
# Out:
# ['task1.pickle']

# %%
model2=joblib.load("task1.pickle")

# %%
N=69
P=47
K=62
temperature=25.05
humidity=90
ph=7
rainfall=261
Total_Nutrients=248
Temperature_Humidity=2000
Log_Rainfall=5

# %%
import numpy as np
new_data = np.array([[N, P, K, temperature, humidity, ph, rainfall, Total_Nutrients,Temperature_Humidity,Log_Rainfall]])

# %%
predicted_crop_names = model2.predict(new_data)

# %%
print("Predicted crop names:", predicted_crop_names)
# Out:
# Predicted crop names: [11]
